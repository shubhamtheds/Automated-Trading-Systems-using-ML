# %% [markdown]
# # Generalization with OOP: The MeanRevBacktester Class

# %% [markdown]
# ## Using the MeanRevBacktester Class

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
plt.style.use("seaborn")

# %%
df = pd.read_csv("intraday_pairs.csv", parse_dates = ["time"], index_col = "time")
df
# Out:
#                              EURUSD    GBPUSD    EURAUD
# time
# 2018-01-01 22:00:00+00:00  1.201205  1.351705  1.533390
# 2018-01-02 04:00:00+00:00  1.207055  1.354830  1.540480
# 2018-01-02 10:00:00+00:00  1.204440  1.357860  1.537980
# 2018-01-02 16:00:00+00:00  1.205800  1.359180  1.540185
# 2018-01-02 22:00:00+00:00  1.204690  1.359530  1.542225
# ...                             ...       ...       ...
# 2019-12-29 22:00:00+00:00  1.119920  1.311810  1.602420
# 2019-12-30 04:00:00+00:00  1.119940  1.311880  1.600800
# 2019-12-30 10:00:00+00:00  1.120095  1.311465  1.601165
# 2019-12-30 16:00:00+00:00  1.119920  1.310990  1.601135
# 2019-12-30 22:00:00+00:00  1.120355  1.312675  1.599830
#
# [2075 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2075 entries, 2018-01-01 22:00:00+00:00 to 2019-12-30 22:00:00+00:00
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   EURUSD  2070 non-null   float64
#  1   GBPUSD  2074 non-null   float64
#  2   EURAUD  2071 non-null   float64
# dtypes: float64(3)
# memory usage: 64.8 KB

# %%
ptc = 0.00007

# %%
import MeanRevBacktester as MeanRev

# %%
tester = MeanRev.MeanRevBacktester("GBPUSD=X", 30, 2, "2022-10-01", "2022-11-21", "5m", ptc)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester
# Out:
# MeanRevBacktester(symbol = GBPUSD=X, SMA = 30, dev = 2, start = 2022-10-01, end = 2022-11-21)

# %%
tester.test_strategy()
# Out:
# (0.969018, -0.098565)

# %%
tester.results
# Out:
#                               price   returns       SMA     Lower     Upper  \
# Datetime
# 2022-10-03 02:30:00+01:00  1.115001  0.000602  1.113614  1.111664  1.115564
# 2022-10-03 02:35:00+01:00  1.114616 -0.000346  1.113635  1.111655  1.115614
# 2022-10-03 02:40:00+01:00  1.114628  0.000011  1.113652  1.111646  1.115657
# 2022-10-03 02:45:00+01:00  1.116022  0.001249  1.113716  1.111536  1.115896
# 2022-10-03 02:50:00+01:00  1.115797 -0.000201  1.113763  1.111465  1.116062
# ...                             ...       ...       ...       ...       ...
# 2022-11-18 22:05:00+00:00  1.189641  0.000000  1.188853  1.187564  1.190141
# 2022-11-18 22:10:00+00:00  1.189641  0.000000  1.188909  1.187635  1.190182
# 2022-11-18 22:15:00+00:00  1.189641  0.000000  1.188954  1.187677  1.190232
# 2022-11-18 22:20:00+00:00  1.189641  0.000000  1.188994  1.187708  1.190280
# 2022-11-18 22:25:00+00:00  1.189641  0.000000  1.189014  1.187706  1.190322
#
#                            distance  position  strategy  trades  creturns  \
# Datetime
# 2022-10-03 02:30:00+01:00  0.001387       0.0  0.000000     0.0  1.000602
# 2022-10-03 02:35:00+01:00  0.000981       0.0 -0.000000     0.0  1.000256
# 2022-10-03 02:40:00+01:00  0.000977       0.0  0.000000     0.0  1.000268
# 2022-11-18 22:05:00+00:00  0.001015       0.0       0.0     0.0  1.068928
# 2022-11-18 22:10:00+00:00  0.000984       0.0       0.0     0.0  1.068928
# 2022-11-18 22:15:00+00:00  0.000950       0.0       0.0     0.0  1.068928
# 2022-11-18 22:20:00+00:00  0.000922       0.0       0.0     0.0  1.068928
# 2022-11-18 22:25:00+00:00  0.000889       0.0       0.0     0.0  1.068928
#
#                            cstrategy
# Datetime
# 2022-10-03 04:15:00+01:00    1.00000
# 2022-10-03 04:20:00+01:00    1.00000
# 2022-10-03 04:25:00+01:00    1.00000
# 2022-10-03 04:30:00+01:00    1.00000
# 2022-10-03 04:35:00+01:00    1.00000
# ...                              ...
# 2022-11-18 22:05:00+00:00    1.02601
# 2022-11-18 22:10:00+00:00    1.02601
# 2022-11-18 22:15:00+00:00    1.02601
# 2022-11-18 22:20:00+00:00    1.02601
# 2022-11-18 22:25:00+00:00    1.02601
#
# [9881 rows x 11 columns]

# %%
tester.results_overview
# Out:
#      SMA  dev  performance
# 0     25    1     0.947180
# 1     25    2     0.980618
# 2     25    3     0.984014
# 3     25    4     0.989199
# 4     26    1     0.947892
# ..   ...  ...          ...
# 295   98    4     0.937324
# 296   99    1     0.934757
# 297   99    2     0.987189
# 298   99    3     0.937160
# 299   99    4     0.932309
#
# [300 rows x 3 columns]

# %%
tester.results_overview.nlargest(10, "performance")
# Out:
#      SMA  dev  performance
# 106   51    3     1.026010
# 102   50    3     1.024084
# 46    36    3     1.023429
# 110   52    3     1.023205
# 98    49    3     1.022506
# 94    48    3     1.019877
# 62    40    3     1.019734
# 86    46    3     1.019672
# 38    34    3     1.019552
# 90    47    3     1.018784

# %%
tester.results_overview.nsmallest(10, "performance")
# Out:
#     SMA  dev  performance
# 44   36    1     0.911084
# 40   35    1     0.912236
# 56   39    1     0.912433
# 36   34    1     0.914260
# 48   37    1     0.914317
# 60   40    1     0.915222
# 68   42    1     0.916894
# 72   43    1     0.917726
# 64   41    1     0.917790
# 24   31    1     0.921677

# %%
ptc = 0

# %% [markdown]
# __Backtesting & Forward Testing__

# %%
train = MeanRev.MeanRevBacktester("EURUSD=X", 30, 2, "2018-01-01", "2018-12-31", "1d", ptc)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
train.optimize_parameters((25, 100, 1), (1, 5, 1)) # in-sample
# Out:
# ((32, 1), 1.093186)

# %%
train.plot_results() # in-sample

# %%
tester = MeanRev.MeanRevBacktester("EURUSD=X", 74, 1, "2019-01-01", "2019-12-31", "1d", ptc) # out-sample
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_strategy()
# Out:
# (1.030651, 0.037618)

# %%
tester.plot_results()

# %% [markdown]
# __GBP/USD__

# %%
tester = MeanRev.MeanRevBacktester("GBPUSD=X", 30, 2, "2018-01-01", "2019-12-31", "1d", 0)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_strategy()
# Out:
# (0.996994, 0.057491)

# %%
tester.plot_results()

# %%
tester.optimize_parameters((25, 100, 1), (1, 5, 1))
# Out:
# ((44, 3), 1.083682)

# %%
tester.plot_results()
